# %% [markdown]
# installing all the libraries

# %%
# %pip install numpy
# %pip install pandas
# %pip install scikit-learn
# %pip install matplotlib
# %pip install seaborn
# %pip install requests
# %pip install paddlepaddle
# %pip install paddleocr

# %% [markdown]
# importing all the libraries

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %% [markdown]
# installing paddleOCR and ollama

# %%
# %pip install ollama
# %pip install paddlepaddle
# %pip install paddleocr
# %pip install paddlepaddle-gpu

# %% [markdown]
# pulling mistral from ollama
#
# first go to your system , download ollama from its officil website-https://ollama.com/download/windows
#
# then after downloading run the command - ollama pull mistral on git bash/cmd
#
# then to run it run the command - ollama run mistral on git bash / cmd
#
# the host address is - 127.0.0.1:11434
